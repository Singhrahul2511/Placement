# %% [markdown]
# ![image.png](attachment:13d6f42b-8d02-44ba-bafd-2b930bf32809.png)

# %%
class Node:
    def __init__(self,prev=None,next = None):
        self.prev = prev
        self.item = item
        self.next = next

class DLL:
    def __init__(self,start=None):
        self.start = start
    def is_empty(self):
        return self.start ==None

    def insert_at_start(self,data):
        n= None(None,data,self.start)
        if not self.is_empty():
            self.start.prev = n
        self.start = n
    def insert_at_last()
