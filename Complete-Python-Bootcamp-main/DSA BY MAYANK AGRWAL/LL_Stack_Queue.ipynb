# %% [markdown]
# ### Steps of Tower OF Hanoi

# %%
def tower_of_hanoi(n,source,destination,auxiliary):
    global step
    if n==0:
        return
    if n==1:
        print(step,source,'-->',destination)
        step +=1
        return
    tower_of_hanoi(n-1,source,auxiliary,destination)
    print(step,source,'-->',destination)
    step +=1
    tower_of_hanoi(n-1,auxiliary,destination,source)
n = 5
step =1 #initialize counter
tower_of_hanoi(n,'source','destination','auxiliary')
# Out:
# 1 source --> destination
# 2 source --> auxiliary
# 3 destination --> auxiliary
# 4 source --> destination
# 5 auxiliary --> source
# 6 auxiliary --> destination
# 7 source --> destination
# 8 source --> auxiliary
# 9 destination --> auxiliary
# 10 destination --> source
# 11 auxiliary --> source
# 12 destination --> auxiliary
# 13 source --> destination
# 14 source --> auxiliary
# 15 destination --> auxiliary
# 16 source --> destination
# 17 auxiliary --> source
# 18 auxiliary --> destination
# 19 source --> destination
# 20 auxiliary --> source
# 21 destination --> auxiliary
# 22 destination --> source
# 23 auxiliary --> source
# 24 auxiliary --> destination
# 25 source --> destination
# 26 source --> auxiliary
# 27 destination --> auxiliary
# 28 source --> destination
# 29 auxiliary --> source
# 30 auxiliary --> destination
# 31 source --> destination

# %% [markdown]
# ### STACK IN PYTHON

# %%
stack = ["Amar", "Akbar", "Anthony"]  
stack.append("Ram")  
stack.append("Iqbal")  
print(stack)  
print(stack.pop())  
print(stack)  
print(stack.pop())  
print(stack)
# Out:
# ['Amar', 'Akbar', 'Anthony', 'Ram', 'Iqbal']
# Iqbal
# ['Amar', 'Akbar', 'Anthony', 'Ram']
# Ram
# ['Amar', 'Akbar', 'Anthony']

# %%
def IS_EMPTY(S):
    if S.top ==None:
        return True 
    return False
S =[]
push(S,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 7
#       5     return False
#       6 S =[]
# ----> 7 push(S,1)
#
# NameError: name 'push' is not defined
