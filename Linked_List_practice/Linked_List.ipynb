# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Node:

  def __init__(self,value):
    self.data = value
    self.next = None

# %%
a = Node(1)
b = Node(2)
c = Node(3)

# %%
print(c.data)
print(id(c))
print(c.next)
print(id(a))
# Out:
# 3
# 1510014544704
# None
# 1510013341472

# %%
a.next = b
b.next = c
print(a.next)
print(b.next)
print(c.next)
# Out:
# ...
# None

# %%
print(c.next)
print(a.next)
print(b.next)
# since a.next is in hgexadecimal values so after converting it into int()
print(int(0x0000015F93CD56A0))
print(int(0x0000015F93E16B40))# this is address of c has been store in b node
# Out:
# None
# ...
# 1510013228704
# 1510014544704

# %%
int(0x7fde268dfdd0)
# Out:
# 140592106307024

# %%
class Node:

  def __init__(self,value):
    self.data = value
    self.next = None

# %%
class LinkedList:

  def __init__(self):

    # Empty Linked List
    self.head = None
    # no of nodes in the LL
    self.n = 0

# magic methos to find len of linked list
  def __len__(self):
    return self.n

  def insert_head(self,value):

    # new node
    new_node = Node(value)

    # create connection
    new_node.next = self.head

    # reassign head
    self.head = new_node

    # increment n
    self.n = self.n + 1

  def __str__(self):

    curr = self.head

    result = ''

    while curr != None:
      result = result + str(curr.data) + '->'
      curr = curr.next

    return result[:-2]
  

  
  ## append node at last of the linked list

  def append(self,value):

    new_node = Node(value)

    if self.head == None:
      # empty
      self.head = new_node
      self.n = self.n + 1
      return

    curr = self.head

    while curr.next != None:
      curr = curr.next

    # you are at the last node
    curr.next = new_node
    self.n = self.n + 1


## insert node at middle of the linked list
  def insert_after(self,after,value):

    new_node = Node(value)

    curr = self.head

    while curr != None:
      if curr.data == after:
        break
      curr = curr.next
#case 1 break -> item aapko mil gya -> curr ->not none
    if curr != None:
      #logic
      new_node.next = curr.next
      curr.next = new_node
      self.n = self.n + 1
    else:
      return 'Item not found'
# case 2 loop pura chla -> item nai mila -> curr -> None

# clear linked list
  def clear(self):
    self.head = None
    self.n = 0


## deleting head one by one
  def delete_head(self):

    if self.head == None:
      # empty
      return 'Empty LL'

    self.head = self.head.next
    self.n = self.n - 1




##delete from last node of linked list
  def pop(self):

    if self.head == None:
      # empty
      return 'Empty LL'

    curr = self.head

    # kya linked list me 1 item hai?
    if curr.next == None:
      # head hi hoga(delete from head)
      return self.delete_head()
      

    while curr.next.next != None:
      curr = curr.next

    # curr -> 2nd last node
    curr.next = None
    self.n = self.n - 1




## delete by item in a linked list
  def remove(self,value):

    if self.head == None:
      return 'Empty LL'

    if self.head.data == value:
      # you want to remove the head node
      return self.delete_head()

    curr = self.head

    while curr.next != None:
      if curr.next.data == value:
        break
      curr = curr.next

    # 2 cases item mil gaya
    # item nai mila
    if curr.next == None:
      # item nai mila
      return 'Not Found'
    else:
      curr.next = curr.next.next
      self.n = self.n - 1





#search by value in linked list it will return posi or index of that element
  def search(self,item):

    curr = self.head
    pos = 0

    while curr != None:
      if curr.data == item:
        return pos
      curr = curr.next
      pos = pos + 1

    return 'Not Found'






#serach item by index in linked list
  def __getitem__(self,index):

    curr = self.head
    pos = 0

    while curr != None:
      if pos == index:
        return curr.data
      curr = curr.next
      pos = pos + 1

    return 'IndexError'

# %%
L = LinkedList()

# %%
L.insert_head(1)
L.append(2)
L.append(3)
L.delete_head()
L.insert_head(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 L.insert_head(1)
#       2 L.append(2)
#       3 L.append(3)
#
# Cell In[1], line 17, in LinkedList.insert_head(self, value)
#      14 def insert_head(self,value):
#      15
#      16   # new node
# ---> 17   new_node = Node(value)
#      19   # create connection
#      20   new_node.next = self.head
#
# NameError: name 'Node' is not defined

# %%
print(L)
# Out:
# 4->4->1->2->3->2->3

# %%
L[4]
# Out:
# 'IndexError'

# %%
print(L)
